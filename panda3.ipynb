# %%
import pandas as pd
import numpy as np

# %%
load_df = pd.read_csv("E:/numpy fundamental/Cancer.csv")
load_df.head()
# Out:
#                        Indicator Name  Cancer Type  Year Country Name  \
# 0  Cancer age-standardized death rate          NaN  2019          NaN
# 1  Cancer age-standardized death rate          NaN  2019          NaN
# 2  Cancer age-standardized death rate          NaN  2019          NaN
# 3  Cancer age-standardized death rate          NaN  2019          NaN
# 4  Cancer age-standardized death rate          NaN  2019          NaN
#
#                          Region   Gender  Area     Numeric  \
# 0                African Region    Total   NaN  100.093775
# 1                African Region    Males   NaN   99.222067
# 2                African Region  Females   NaN  103.394290
# 3  Eastern Mediterranean Region    Total   NaN   91.684712
# 4  Eastern Mediterranean Region    Males   NaN  100.215360
#
#   Lower Confidence Limit Upper Confidence Limit  Comment  Unnamed: 11
# 0                no data                no data      NaN          NaN
# ...

# %%
# slicing
load_df[1:6]
# Out:
#                        Indicator Name  Cancer Type  Year Country Name  \
# 1  Cancer age-standardized death rate          NaN  2019          NaN
# 2  Cancer age-standardized death rate          NaN  2019          NaN
# 3  Cancer age-standardized death rate          NaN  2019          NaN
# 4  Cancer age-standardized death rate          NaN  2019          NaN
# 5  Cancer age-standardized death rate          NaN  2019          NaN
#
#                          Region   Gender  Area     Numeric  \
# 1                African Region    Males   NaN   99.222067
# 2                African Region  Females   NaN  103.394290
# 3  Eastern Mediterranean Region    Total   NaN   91.684712
# 4  Eastern Mediterranean Region    Males   NaN  100.215360
# 5  Eastern Mediterranean Region  Females   NaN   84.058661
#
#   Lower Confidence Limit Upper Confidence Limit  Comment  Unnamed: 11
# 1                no data                no data      NaN          NaN
# ...

# %%
# using df.column
region_lc = load_df.Region
region_lc.head()
# Out:
# 0                  African Region
# 1                  African Region
# 2                  African Region
# 3    Eastern Mediterranean Region
# 4    Eastern Mediterranean Region
# Name: Region, dtype: object

# %%
# selecting using column name
colname = load_df.Gender
colname.head()
# Out:
# 0      Total
# 1      Males
# 2    Females
# 3      Total
# 4      Males
# Name: Gender, dtype: object

# %%
load_df
# Out:
#                                          Indicator Name  Cancer Type  Year  \
# 0                    Cancer age-standardized death rate          NaN  2019
# 1                    Cancer age-standardized death rate          NaN  2019
# 2                    Cancer age-standardized death rate          NaN  2019
# 3                    Cancer age-standardized death rate          NaN  2019
# 4                    Cancer age-standardized death rate          NaN  2019
# ...                                                 ...          ...   ...
# 1135  Percentage of cancer deaths occurring under 70...          NaN  2019
# 1136  Percentage of cancer deaths occurring under 70...          NaN  2019
# 1137  Percentage of cancer deaths occurring under 70...          NaN  2019
# 1138  Percentage of cancer deaths occurring under 70...          NaN  2019
# 1139  Percentage of cancer deaths occurring under 70...          NaN  2019
#
# ...

# %%
# modified indexing usie 'inplace = true'
modified_indexing_df = load_df
modified_indexing_df.set_index('Numeric',inplace=True)
modified_indexing_df.head()
# Out:
#                                 Indicator Name  Cancer Type  Year  \
# Numeric
# 100.093775  Cancer age-standardized death rate          NaN  2019
# 99.222067   Cancer age-standardized death rate          NaN  2019
# 103.394290  Cancer age-standardized death rate          NaN  2019
# 91.684712   Cancer age-standardized death rate          NaN  2019
# 100.215360  Cancer age-standardized death rate          NaN  2019
#
#            Country Name                        Region   Gender  Area  \
# Numeric
# 100.093775          NaN                African Region    Total   NaN
# 99.222067           NaN                African Region    Males   NaN
# 103.394290          NaN                African Region  Females   NaN
# 91.684712           NaN  Eastern Mediterranean Region    Total   NaN
# 100.215360          NaN  Eastern Mediterranean Region    Males   NaN
#
#            Lower Confidence Limit Upper Confidence Limit  Comment  Unnamed: 11
# Numeric
# ...

# %%
# reseting the indexiing
modified_indexing_df.reset_index(inplace = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-6beb0500758d> in <module>
#       1 # reseting the indexiing
# ----> 2 modified_indexing_df.reset_index(inplace = True)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5797                     )
#    5798
# -> 5799                 new_obj.insert(0, name, level_values)
#    5800
#    5801         new_obj.index = new_index
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
# ...

# %%
modified_indexing_df.head()
# Out:
#    level_0  index     Numeric  Year                      Indicator Name  \
# 0        0      0  100.093775  2019  Cancer age-standardized death rate
# 1        1      1   99.222067  2019  Cancer age-standardized death rate
# 2        2      2  103.394290  2019  Cancer age-standardized death rate
# 3        3      3   91.684712  2019  Cancer age-standardized death rate
# 4        4      4  100.215360  2019  Cancer age-standardized death rate
#
#    Cancer Type Country Name                        Region   Gender  Area  \
# 0          NaN          NaN                African Region    Total   NaN
# 1          NaN          NaN                African Region    Males   NaN
# 2          NaN          NaN                African Region  Females   NaN
# 3          NaN          NaN  Eastern Mediterranean Region    Total   NaN
# 4          NaN          NaN  Eastern Mediterranean Region    Males   NaN
#
#   Lower Confidence Limit Upper Confidence Limit  Comment  Unnamed: 11
# ...

# %%
# To reset the index of a column in a DataFrame in Python, you can use the reset_index() method. Here's how you can reset the index for the colname column
colname = load_df.Gender
colname_reset = colname.reset_index(drop=True)
colname_reset.head()
# Out:
# 0      Total
# 1      Males
# 2    Females
# 3      Total
# 4      Males
# Name: Gender, dtype: object

# %%
modified_indexing_df.set_index('Numeric',inplace=True)
modified_indexing_df.head()
# Out:
#             Year                      Indicator Name  Cancer Type  \
# Numeric
# 100.093775  2019  Cancer age-standardized death rate          NaN
# 99.222067   2019  Cancer age-standardized death rate          NaN
# 103.394290  2019  Cancer age-standardized death rate          NaN
# 91.684712   2019  Cancer age-standardized death rate          NaN
# 100.215360  2019  Cancer age-standardized death rate          NaN
#
#            Country Name                        Region   Gender  Area  \
# Numeric
# 100.093775          NaN                African Region    Total   NaN
# 99.222067           NaN                African Region    Males   NaN
# 103.394290          NaN                African Region  Females   NaN
# 91.684712           NaN  Eastern Mediterranean Region    Total   NaN
# 100.215360          NaN  Eastern Mediterranean Region    Males   NaN
#
#            Lower Confidence Limit Upper Confidence Limit  Comment  Unnamed: 11
# Numeric
# ...

# %%
print(modified_indexing_df['Numeric'].unique())

# %%
# access few columns roe value based on index values
modified_indexing_df.loc[[91.684712],'Year':'Region']

# %%
# access rows based on logical values
modified_indexing_df.loc[[True,True,False,True,False]]

# %% [markdown]
# # df.iloc

# %%
modified_indexing_df.head()
# Out:
#    level_0  index     Numeric  Year                      Indicator Name  \
# 0        0      0  100.093775  2019  Cancer age-standardized death rate
# 1        1      1   99.222067  2019  Cancer age-standardized death rate
# 2        2      2  103.394290  2019  Cancer age-standardized death rate
# 3        3      3   91.684712  2019  Cancer age-standardized death rate
# 4        4      4  100.215360  2019  Cancer age-standardized death rate
#
#    Cancer Type Country Name                        Region   Gender  Area  \
# 0          NaN          NaN                African Region    Total   NaN
# 1          NaN          NaN                African Region    Males   NaN
# 2          NaN          NaN                African Region  Females   NaN
# 3          NaN          NaN  Eastern Mediterranean Region    Total   NaN
# 4          NaN          NaN  Eastern Mediterranean Region    Males   NaN
#
#   Lower Confidence Limit Upper Confidence Limit  Comment  Unnamed: 11
# ...

# %%
modified_indexing_df.iloc[0,3]
# first row fourth column
# Out:
# 2019

# %%
modified_indexing_df.iloc[:3]
# Out:
#    level_0  index     Numeric  Year                      Indicator Name  \
# 0        0      0  100.093775  2019  Cancer age-standardized death rate
# 1        1      1   99.222067  2019  Cancer age-standardized death rate
# 2        2      2  103.394290  2019  Cancer age-standardized death rate
#
#    Cancer Type Country Name          Region   Gender  Area  \
# 0          NaN          NaN  African Region    Total   NaN
# 1          NaN          NaN  African Region    Males   NaN
# 2          NaN          NaN  African Region  Females   NaN
#
#   Lower Confidence Limit Upper Confidence Limit  Comment  Unnamed: 11
# 0                no data                no data      NaN          NaN
# 1                no data                no data      NaN          NaN
# 2                no data                no data      NaN          NaN

# %%
# Store the current index in a separate column
modified_indexing_df['previous_index'] = modified_indexing_df.index

# %%
# Remove the 'level_0' column if needed
modified_indexing_df.drop('level_0', axis=1, inplace=True)

# %%
# Out:
#       index     Numeric  Year  \
# 0         0  100.093775  2019
# 1         1   99.222067  2019
# 2         2  103.394290  2019
# 3         3   91.684712  2019
# 4         4  100.215360  2019
# ...     ...         ...   ...
# 1135   1135   73.015951  2019
# 1136   1136   81.544289  2019
# 1137   1137   68.934731  2019
# 1138   1138   65.084667  2019
# 1139   1139   71.065408  2019
#
#                                          Indicator Name  Cancer Type  \
# 0                    Cancer age-standardized death rate          NaN
# 1                    Cancer age-standardized death rate          NaN
# 2                    Cancer age-standardized death rate          NaN
# 3                    Cancer age-standardized death rate          NaN
# 4                    Cancer age-standardized death rate          NaN
# ...                                                 ...          ...
# 1135  Percentage of cancer deaths occurring under 70...          NaN
# ...

# %%
modified_indexing_df.drop('index',axis=1, inplace=True)

# %%
modified_indexing_df
# Out:
#          Numeric  Year                                     Indicator Name  \
# 0     100.093775  2019                 Cancer age-standardized death rate
# 1      99.222067  2019                 Cancer age-standardized death rate
# 2     103.394290  2019                 Cancer age-standardized death rate
# 3      91.684712  2019                 Cancer age-standardized death rate
# 4     100.215360  2019                 Cancer age-standardized death rate
# ...          ...   ...                                                ...
# 1135   73.015951  2019  Percentage of cancer deaths occurring under 70...
# 1136   81.544289  2019  Percentage of cancer deaths occurring under 70...
# 1137   68.934731  2019  Percentage of cancer deaths occurring under 70...
# 1138   65.084667  2019  Percentage of cancer deaths occurring under 70...
# 1139   71.065408  2019  Percentage of cancer deaths occurring under 70...
#
#       Cancer Type Country Name                        Region   Gender  Area  \
# ...

# %%
modified_indexing_df.iloc[:3]
# Out:
#       Numeric  Year                      Indicator Name  Cancer Type  \
# 0  100.093775  2019  Cancer age-standardized death rate          NaN
# 1   99.222067  2019  Cancer age-standardized death rate          NaN
# 2  103.394290  2019  Cancer age-standardized death rate          NaN
#
#   Country Name          Region   Gender  Area Lower Confidence Limit  \
# 0          NaN  African Region    Total   NaN                no data
# 1          NaN  African Region    Males   NaN                no data
# 2          NaN  African Region  Females   NaN                no data
#
#   Upper Confidence Limit  Comment  Unnamed: 11  previous_index
# 0                no data      NaN          NaN               0
# 1                no data      NaN          NaN               1
# 2                no data      NaN          NaN               2

# %%
modified_indexing_df.iloc[0,3]
# Out:
# nan

# %%
modified_indexing_df.iloc[0,5]
# Out:
# 'African Region'

# %%
modified_indexing_df
# Out:
#                                                Indicator Name  Cancer Type  \
# Numeric
# 100.093775                 Cancer age-standardized death rate          NaN
# 99.222067                  Cancer age-standardized death rate          NaN
# 103.394290                 Cancer age-standardized death rate          NaN
# 91.684712                  Cancer age-standardized death rate          NaN
# 100.215360                 Cancer age-standardized death rate          NaN
# ...                                                       ...          ...
# 73.015951   Percentage of cancer deaths occurring under 70...          NaN
# 81.544289   Percentage of cancer deaths occurring under 70...          NaN
# 68.934731   Percentage of cancer deaths occurring under 70...          NaN
# 65.084667   Percentage of cancer deaths occurring under 70...          NaN
# 71.065408   Percentage of cancer deaths occurring under 70...          NaN
#
# ...

# %%
# accessing multiple rows
modified_indexing_df.iloc[[0,3,4]]
# Out:
#                                 Indicator Name  Cancer Type  Year  \
# Numeric
# 100.093775  Cancer age-standardized death rate          NaN  2019
# 91.684712   Cancer age-standardized death rate          NaN  2019
# 100.215360  Cancer age-standardized death rate          NaN  2019
#
#            Country Name                        Region Gender  Area  \
# Numeric
# 100.093775          NaN                African Region  Total   NaN
# 91.684712           NaN  Eastern Mediterranean Region  Total   NaN
# 100.215360          NaN  Eastern Mediterranean Region  Males   NaN
#
#            Lower Confidence Limit Upper Confidence Limit  Comment  Unnamed: 11
# Numeric
# 100.093775                no data                no data      NaN          NaN
# 91.684712                 no data                no data      NaN          NaN
# 100.215360                no data                no data      NaN          NaN

# %%
modified_indexing_df.iloc[[0,3,4],:]
# Out:
#                                 Indicator Name  Cancer Type  Year  \
# Numeric
# 100.093775  Cancer age-standardized death rate          NaN  2019
# 91.684712   Cancer age-standardized death rate          NaN  2019
# 100.215360  Cancer age-standardized death rate          NaN  2019
#
#            Country Name                        Region Gender  Area  \
# Numeric
# 100.093775          NaN                African Region  Total   NaN
# 91.684712           NaN  Eastern Mediterranean Region  Total   NaN
# 100.215360          NaN  Eastern Mediterranean Region  Males   NaN
#
#            Lower Confidence Limit Upper Confidence Limit  Comment  Unnamed: 11
# Numeric
# 100.093775                no data                no data      NaN          NaN
# 91.684712                 no data                no data      NaN          NaN
# 100.215360                no data                no data      NaN          NaN

# %%
modified_indexing_df.iloc[1:2,0:3].head()
# Out:
#                                Indicator Name  Cancer Type  Year
# Numeric
# 99.222067  Cancer age-standardized death rate          NaN  2019

# %%
# condition based subsetting
# Return boolean
modified_indexing_df['Year'] > 100
modified_indexing_df.Year >100
# Out:
# Numeric
# 100.093775    True
# 99.222067     True
# 103.394290    True
# 91.684712     True
# 100.215360    True
#               ...
# 73.015951     True
# 81.544289     True
# 68.934731     True
# 65.084667     True
# 71.065408     True
# Name: Year, Length: 1140, dtype: bool
