# %% [markdown]
# # play with Data
# ## focus on :
# ## select column from dataframe
# ## select rows from dataframe
# ## sebsetting of dataframes-df[start_index:end_index]

# %%
import numpy as np
import pandas as pd

# %%
loan_df = pd.read_csv("path\loan.csv")
loan_df.head()

# %%
# selecting alternate rows
loan_df[0::2].head()

# %%
# slicing, upper bound is not selcted in python i.e only four records will display, i.e index 1 daykhe 4 shamo denxa
loan_df[1:5]

# %%
# reasult is going to be dataframe but not series 
loan_df[['loan_amt']].head()

# %%
# selectiong the multiple columns df['column1', 'column2','column3']
loan_df [['member_id','loan_amt','fund_amt']].head()

# %%
# trying to select the fifth index row
# 5 is column name
loan_df[4] # it will throw error, insted of it we set index
loan_df.set_index('member_id').head()

# %% [markdown]
# # indexing
# ## beacuse a pandas has confusion about label based value selection or index based value selection
# ## so, we use Label based indexing using df.loc
# ## Position based indexing using df.iloc

# %%
help(pd.DataFrame.loc)
# Out:
# Help on property:
#
#     Access a group of rows and columns by label(s) or a boolean array.
#
#     ``.loc[]`` is primarily label based, but may also be used with a
#     boolean array.
#
#     Allowed inputs are:
#
#     - A single label, e.g. ``5`` or ``'a'``, (note that ``5`` is
#       interpreted as a *label* of the index, and **never** as an
#       integer position along the index).
#     - A list or array of labels, e.g. ``['a', 'b', 'c']``.
#     - A slice object with labels, e.g. ``'a':'f'``.
#
#       .. warning:: Note that contrary to usual python slices, **both** the
#           start and the stop are included
#
#     - A boolean array of the same length as the axis being sliced,
#       e.g. ``[True, False, True]``.
#     - An alignable boolean Series. The index of the key will be aligned before
#       masking.
#     - An alignable Index. The Index of the returned selection will be the input.
#     - A ``callable`` function with one argument (the calling Series or
# ...

# %%
# selection a single element
# read a row label = 4 and column label = 'member_id'
loan_df.loc[4,'member_id']

# %%
# picking up the whole row whose label value is 4
loan_df.loc[4]
